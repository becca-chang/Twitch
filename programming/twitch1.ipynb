# %% [markdown]
# ## get user by name

# %%
import requests

url = "https://api.twitch.tv/helix/users?login=HasanAbi&login=zackrawrr&login=KaiCenat"

payload = {}
headers = {
  'Client-Id': 'olj1zlf45mtffa1166zd8b1ersrew3',
  'Authorization': 'Bearer ao05bvk118sgvfolodd8c585pidnzh'
}

response = requests.request("GET", url, headers=headers, data=payload)
user_id = response.json()
print(response.text)
print(user_id)
# Out:
# {"data":[{"id":"207813352","login":"hasanabi","display_name":"HasanAbi","type":"","broadcaster_type":"partner","description":"i'm a political commentator irl trying to avoid heated gaming moments","profile_image_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/0347a9aa-e396-49a5-b0f1-31261704bab8-profile_image-300x300.jpeg","offline_image_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/fb8e7284-9745-484c-9e17-2387cdb2a3a8-channel_offline_image-1920x1080.png","view_count":0,"created_at":"2018-03-23T20:06:49Z"},{"id":"552120296","login":"zackrawrr","display_name":"zackrawrr","type":"","broadcaster_type":"","description":"goat sex bird man","profile_image_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/a9ce83ba-c0bd-49cc-83bd-9d17647a211a-profile_image-300x300.png","offline_image_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/6f6c88bb-5a09-4049-9f96-2adcf3b4bdb3-channel_offline_image-1920x1080.jpeg","view_count":0,"created_at":"2020-07-07T19:40:44Z"},{"id":"641972806","login":"kaicenat","display_name":"KaiCenat","type":"","broadcaster_type":"partner","description":"Come Through \u0026 Watch These Litt STREAMS! ","profile_image_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/1d8cd548-04fa-49fb-bfcd-f222f73482b6-profile_image-300x300.png","offline_image_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/f1f30438-f4b1-45ae-8054-fa0f4e468e85-channel_offline_image-1920x1080.jpeg","view_count":0,"created_at":"2021-01-27T01:55:08Z"}]}
# {'data': [{'id': '207813352', 'login': 'hasanabi', 'display_name': 'HasanAbi', 'type': '', 'broadcaster_type': 'partner', 'description': "i'm a political commentator irl trying to avoid heated gaming moments", 'profile_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/0347a9aa-e396-49a5-b0f1-31261704bab8-profile_image-300x300.jpeg', 'offline_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/fb8e7284-9745-484c-9e17-2387cdb2a3a8-channel_offline_image-1920x1080.png', 'view_count': 0, 'created_at': '2018-03-23T20:06:49Z'}, {'id': '552120296', 'login': 'zackrawrr', 'display_name': 'zackrawrr', 'type': '', 'broadcaster_type': '', 'description': 'goat sex bird man', 'profile_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/a9ce83ba-c0bd-49cc-83bd-9d17647a211a-profile_image-300x300.png', 'offline_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/6f6c88bb-5a09-4049-9f96-2adcf3b4bdb3-channel_offline_image-1920x1080.jpeg', 'view_count': 0, 'created_at': '2020-07-07T19:40:44Z'}, {'id': '641972806', 'login': 'kaicenat', 'display_name': 'KaiCenat', 'type': '', 'broadcaster_type': 'partner', 'description': 'Come Through & Watch These Litt STREAMS! ', 'profile_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/1d8cd548-04fa-49fb-bfcd-f222f73482b6-profile_image-300x300.png', 'offline_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/f1f30438-f4b1-45ae-8054-fa0f4e468e85-channel_offline_image-1920x1080.jpeg', 'view_count': 0, 'created_at': '2021-01-27T01:55:08Z'}]}
